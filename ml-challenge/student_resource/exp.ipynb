# %%
import pandas as pd

# %%
df_src1= pd.read_csv('/home/ubuntu/Desktop/ml-challenge/student_resource/dataset/train/train_source1.tsv', sep='\t', header=None)
df_src2= pd.read_csv('/home/ubuntu/Desktop/ml-challenge/student_resource/dataset/train/train_source2.tsv', sep='\t', header=None)
df_src3= pd.read_csv('/home/ubuntu/Desktop/ml-challenge/student_resource/dataset/train/train_source3.tsv', sep='\t', header=None)
print(df_src1.head())
print()

print(df_src2.head())
print()

print(df_src3.head())
# Out:
#               0                    1  \
# 0     entity_id        business_name
# 1  S1-925783039  Orelee's Barbershop
# 2  S1-773889195          Prime Money
# 3  S1-377745466        B+ Retail Inc
# 4  S1-133037285        Christ Chapel
#
#                                                    2        3
# 0                                   business_address  country
# 1             1795 Westchester Drive, High Point, NC       US
# 2                    17560 Ellis Road, Tahlequah, OK       US
# 3                1712 Montebello Avenue, Phoenix, AZ       US
# 4  2100 Cameron Drive, Unit APARTMENT G, Dundalk, MD       US
#
#               0                                1  \
# 0     entity_id                    business_name
# 1  S2-166376419  राम मार्केटिंग प्राइवेट लिमिटेड
# 2  S2-764573417     -- Holloway Peak Inc Seafood
# 3  S2-639257739         आदित्य प्रॉपर्टीज एलएलपी
# 4  S2-163963287                       Summit Inc
#
#                                                   2        3
# ...

# %%
import torch
print(torch.__version__)
torch.cuda.is_available()
# Out:
# 2.7.0+cu128
# False

# %%
df_src1.shape
# Out:
# (2206822, 3)

# %%
df_src1.isnull().sum()
# Out:
# id       0
# text     0
# label    0
# dtype: int64
